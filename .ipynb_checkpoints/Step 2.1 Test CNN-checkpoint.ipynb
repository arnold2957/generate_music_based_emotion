# %%
import pretty_midi
import numpy as np
import matplotlib.pyplot as plt
import os
import math
import numpy as np
np.set_printoptions(threshold=np.inf)

import time

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
with open(r'data\1. 400-100 dataset\midi_cnn.json','r') as load_f:
    dataset = json.load(load_f)
    x_train = np.asarray(dataset["x_train"])
    x_test = np.asarray(dataset["x_test"])
    y_a_train = np.asarray(dataset["y_a_train"])
    y_a_test = np.asarray(dataset["y_a_test"])
    y_v_train = np.asarray(dataset["y_v_train"])
    y_v_test = np.asarray(dataset["y_v_test"])

# data reshape
x_train = x_train.reshape(24000,50,128,1)
x_test = x_test.reshape(6000,50,128,1)
y_a_train = y_a_train.reshape(24000,1)
y_a_test = y_a_test.reshape(6000,1)
y_v_train = y_v_train.reshape(24000,1)
y_v_test = y_v_test.reshape(6000,1)

# %%
def cnn_va(x):
    arousal = layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding="same")(x)
    arousal = layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding="same")(arousal)
    arousal = layers.MaxPooling2D(pool_size=(2, 2),strides=(2, 2),padding='valid')(arousal)

    arousal = layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding="same")(arousal)
    arousal = layers.MaxPooling2D(pool_size=(3, 3),strides=(3, 3),padding='valid')(arousal)
    arousal = layers.Dropout(0.25)(arousal)

    arousal = layers.Conv2D(filters=256, kernel_size=3, activation='relu', padding="same")(arousal)
    arousal = layers.MaxPooling2D(pool_size=(3, 3),strides=(3, 3),padding='valid')(arousal)
    arousal = layers.Dropout(0.25)(arousal)

    arousal = layers.Conv2D(filters=256, kernel_size=3, activation='relu', padding="same")(arousal)
    arousal = layers.MaxPooling2D(pool_size=(1, 3),strides=(3, 3),padding='valid')(arousal)
    arousal = layers.Dropout(0.25)(arousal)

    arousal = layers.Flatten()(arousal)

    arousal = layers.Dense(256)(arousal)
    arousal = layers.Dropout(0.5)(arousal)

    arousal = layers.Dense(256)(arousal)
    arousal = layers.Dropout(0.5)(arousal)

    arousal = layers.Dense(1)(arousal)

    return arousal

def Cnn():
    input_data = layers.Input((50, 128,1))

    x =layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding="same")(input_data)
    x =layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding="same")(x)
    x =layers.MaxPooling2D(pool_size=(2, 2),strides=(2, 2),padding='valid')(x)
    
    model = keras.Model(inputs=input_data, outputs=[cnn_va(x), cnn_va(x)])
    model.compile(loss = ["mean_squared_error","mean_squared_error"], optimizer='adam')

    return model

model_cnn = Cnn()
model_cnn.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50, 128, 1)] 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 50, 128, 64)  640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 50, 128, 64)  36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 25, 64, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 25, 64, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 64, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 64, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 64, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 12, 32, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 12, 32, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 12, 32, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 12, 32, 128)  73856       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 4, 10, 128)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 4, 10, 128)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 4, 10, 128)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 4, 10, 128)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 4, 10, 256)   295168      dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 4, 10, 256)   295168      dropout_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 1, 3, 256)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 1, 3, 256)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1, 3, 256)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 1, 3, 256)    0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 3, 256)    590080      dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 3, 256)    590080      dropout_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 1, 1, 256)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 1, 1, 256)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1, 1, 256)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 1, 1, 256)    0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           dropout_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           dropout_7[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          65792       flatten[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          65792       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 256)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          65792       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 256)          65792       dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 256)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            257         dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            257         dropout_9[0][0]
# ==================================================================================================
# Total params: 2,367,170
# Trainable params: 2,367,170
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
print(time.asctime(time.localtime(time.time())),"\n")
model_cnn = Cnn()
model_cnn.fit(
    x_train,[y_a_train,y_v_train], 
    epochs=5, batch_size=10,
    validation_data=(x_test, [y_a_test,y_v_test]),verbose=1)
# verbose means shows log or not 0:nothing 1: epoch result + bar 2:only epoch result
print('loss on ',model_cnn.evaluate(x_test,[y_a_test,y_v_test], verbose=0)[0])
print(time.asctime(time.localtime(time.time())),"\n")
# Out:
# Thu Oct  1 23:48:31 2020
#
# Train on 24000 samples, validate on 6000 samples
# Epoch 1/5
# 24000/24000 [==============================] - 2925s 122ms/sample - loss: 0.1234 - dense_14_loss: 0.0663 - dense_17_loss: 0.0572 - val_loss: 0.0962 - val_dense_14_loss: 0.0471 - val_dense_17_loss: 0.0491
# Epoch 2/5
# 24000/24000 [==============================] - 2809s 117ms/sample - loss: 0.1049 - dense_14_loss: 0.0541 - dense_17_loss: 0.0508 - val_loss: 0.0979 - val_dense_14_loss: 0.0499 - val_dense_17_loss: 0.0480
# Epoch 3/5
# 24000/24000 [==============================] - 2819s 117ms/sample - loss: 0.1002 - dense_14_loss: 0.0513 - dense_17_loss: 0.0489 - val_loss: 0.1042 - val_dense_14_loss: 0.0574 - val_dense_17_loss: 0.0467
# Epoch 4/5
# 24000/24000 [==============================] - 2800s 117ms/sample - loss: 0.0995 - dense_14_loss: 0.0508 - dense_17_loss: 0.0486 - val_loss: 0.0966 - val_dense_14_loss: 0.0495 - val_dense_17_loss: 0.0471
# Epoch 5/5
# 24000/24000 [==============================] - 2801s 117ms/sample - loss: 0.0980 - dense_14_loss: 0.0498 - dense_17_loss: 0.0482 - val_loss: 0.0959 - val_dense_14_loss: 0.0496 - val_dense_17_loss: 0.0463
# loss on  0.09591860901316007
# Fri Oct  2 03:47:07 2020

# %%
with open(r'data\1. 400-100 dataset\wav_cnn.json','r') as load_f:
    dataset = json.load(load_f)
    x_train = np.asarray(dataset["x_train"])
    x_test = np.asarray(dataset["x_test"])
    y_a_train = np.asarray(dataset["y_a_train"])
    y_a_test = np.asarray(dataset["y_a_test"])
    y_v_train = np.asarray(dataset["y_v_train"])
    y_v_test = np.asarray(dataset["y_v_test"])

# data reshape
x_train = x_train.reshape(24000,50,128,1)
x_test = x_test.reshape(6000,50,128,1)
y_a_train = y_a_train.reshape(24000,1)
y_a_test = y_a_test.reshape(6000,1)
y_v_train = y_v_train.reshape(24000,1)
y_v_test = y_v_test.reshape(6000,1)

# %%
print(time.asctime(time.localtime(time.time())),"\n")
model_cnn = Cnn()
model_cnn.fit(
    x_train,[y_a_train,y_v_train], 
    epochs=5, batch_size=10,
    validation_data=(x_test, [y_a_test,y_v_test]),verbose=2)
# verbose means shows log or not 0:nothing 1: epoch result + bar 2:only epoch result
print('loss on ',model_cnn.evaluate(x_test,[y_a_test,y_v_test], verbose=0)[0])
print(time.asctime(time.localtime(time.time())),"\n")
